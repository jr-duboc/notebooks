# %%
# Calculating the CDF of a normal distribution at a given point
from scipy.stats import norm
import matplotlib.pyplot as plt
import numpy as np

mu=9
sigma = 36
s = np.random.normal(9, 36, 1000)
count, bins, ignored = plt.hist(s, 30, normed=True)
plt.plot(bins,s, linewidth=2, color='r')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-42a914c3155c> in <module>
#       8 s = np.random.normal(9, 36, 1000)
#       9 count, bins, ignored = plt.hist(s, 30, normed=True)
# ---> 10 plt.plot(bins,s, linewidth=2, color='r')
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...
